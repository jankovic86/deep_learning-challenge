# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.

app_df = application_df.drop(columns=["EIN", "NAME"])
app_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.

app_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning

application_counts = app_df["APPLICATION_TYPE"].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# application_types_to_replace = ["T9", "T13", "T12", "T2", "T25", "T14", "T29", "T15", "T17"]
application_types_to_replace = []
for index, val in application_counts.items():
    if val <= 500:
        application_types_to_replace.append(index)

# Replace in dataframe
for app in application_types_to_replace:
    app_df['APPLICATION_TYPE'] = app_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_count = app_df["CLASSIFICATION"].value_counts()
class_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C5200        1
# C1820        1
# C1370        1
# C1248        1
# C1732        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
app_df["CLASSIFICATION"].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C4100        6
# C2400        6
# C1720        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1256        2
# C1267        2
# C1246        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = []
for index, val in class_count.items():
    if val <= 1000:
        classifications_to_replace.append(index)


# Replace in dataframe
for cls in classifications_to_replace:
    app_df['CLASSIFICATION'] = app_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
app_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`

num_df = pd.get_dummies(app_df)
num_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays

y = num_df["IS_SUCCESSFUL"]
X = num_df.drop("IS_SUCCESSFUL", axis=1)


# Split the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X.shape
# Out:
# (34299, 43)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# # Optimization #1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

features = 43
node1 = 6
node2 = 6
# node3 = 6
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=node1, activation="relu", input_dim=features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=node2, activation="tanh"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 6)                 264
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 1)                 7
#
# ...
# Total params: 313
# Trainable params: 313
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model

nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6305 - accuracy: 0.6558
# Epoch 2/200
# 804/804 [==============================] - 1s 977us/step - loss: 0.5739 - accuracy: 0.7222
# Epoch 3/200
# 804/804 [==============================] - 1s 785us/step - loss: 0.5635 - accuracy: 0.7258
# Epoch 4/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5594 - accuracy: 0.7279
# Epoch 5/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5575 - accuracy: 0.7283
# Epoch 6/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5564 - accuracy: 0.7292
# Epoch 7/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5550 - accuracy: 0.7307
# Epoch 8/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5541 - accuracy: 0.7296
# Epoch 9/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7301
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5512 - accuracy: 0.7290 - 250ms/epoch - 932us/step
# Loss: 0.5512016415596008, Accuracy: 0.7289795875549316

# %% [markdown]
# # Optimization #2

# %%
features = 43
node1 = 10
node2 = 8
# node3 = 6
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=node1, activation="sigmoid", input_dim=features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=node2, activation="sigmoid"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 10)                440
#
#  dense_4 (Dense)             (None, 8)                 88
#
#  dense_5 (Dense)             (None, 1)                 9
#
# ...
# Total params: 537
# Trainable params: 537
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 696us/step - loss: 0.6375 - accuracy: 0.6627
# Epoch 2/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5763 - accuracy: 0.7248
# Epoch 3/100
# 804/804 [==============================] - 1s 715us/step - loss: 0.5709 - accuracy: 0.7269
# Epoch 4/100
# 804/804 [==============================] - 1s 792us/step - loss: 0.5669 - accuracy: 0.7282
# Epoch 5/100
# 804/804 [==============================] - 1s 722us/step - loss: 0.5639 - accuracy: 0.7282
# Epoch 6/100
# 804/804 [==============================] - 1s 809us/step - loss: 0.5614 - accuracy: 0.7292
# Epoch 7/100
# 804/804 [==============================] - 1s 754us/step - loss: 0.5596 - accuracy: 0.7298
# Epoch 8/100
# 804/804 [==============================] - 1s 731us/step - loss: 0.5583 - accuracy: 0.7292
# Epoch 9/100
# 804/804 [==============================] - 1s 863us/step - loss: 0.5573 - accuracy: 0.7296
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5514 - accuracy: 0.7290 - 199ms/epoch - 742us/step
# Loss: 0.5514203310012817, Accuracy: 0.7289795875549316

# %% [markdown]
# # Optimization #3

# %%
features = 43
node1 = 15
node2 = 10
# node3 = 6
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=node1, activation="relu", input_dim=features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=node2, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 15)                660
#
#  dense_7 (Dense)             (None, 10)                160
#
#  dense_8 (Dense)             (None, 1)                 11
#
# ...
# Total params: 831
# Trainable params: 831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 709us/step - loss: 0.5901 - accuracy: 0.7076
# Epoch 2/100
# 804/804 [==============================] - 1s 696us/step - loss: 0.5580 - accuracy: 0.7287
# Epoch 3/100
# 804/804 [==============================] - 1s 700us/step - loss: 0.5546 - accuracy: 0.7294
# Epoch 4/100
# 804/804 [==============================] - 1s 705us/step - loss: 0.5527 - accuracy: 0.7303
# Epoch 5/100
# 804/804 [==============================] - 1s 725us/step - loss: 0.5514 - accuracy: 0.7305
# Epoch 6/100
# 804/804 [==============================] - 1s 826us/step - loss: 0.5504 - accuracy: 0.7310
# Epoch 7/100
# 804/804 [==============================] - 1s 899us/step - loss: 0.5495 - accuracy: 0.7319
# Epoch 8/100
# 804/804 [==============================] - 1s 726us/step - loss: 0.5489 - accuracy: 0.7311
# Epoch 9/100
# 804/804 [==============================] - 1s 724us/step - loss: 0.5481 - accuracy: 0.7323
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5549 - accuracy: 0.7265 - 204ms/epoch - 762us/step
# Loss: 0.5548657774925232, Accuracy: 0.7265306115150452

# %% [markdown]
# # Optimization #4

# %%
features = 43
node1 = 15
node2 = 10
# node3 = 6
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=node1, activation="tanh", input_dim=features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=node2, activation="tanh"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="tanh"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 15)                660
#
#  dense_10 (Dense)            (None, 10)                160
#
#  dense_11 (Dense)            (None, 1)                 11
#
# ...
# Total params: 831
# Trainable params: 831
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 744us/step - loss: 2.0199 - accuracy: 0.6192
# Epoch 2/100
# 804/804 [==============================] - 1s 741us/step - loss: 0.9364 - accuracy: 0.6910
# Epoch 3/100
# 804/804 [==============================] - 1s 931us/step - loss: 0.8203 - accuracy: 0.7053
# Epoch 4/100
# 804/804 [==============================] - 1s 906us/step - loss: 0.7951 - accuracy: 0.7224
# Epoch 5/100
# 804/804 [==============================] - 1s 970us/step - loss: 0.7432 - accuracy: 0.7259
# Epoch 6/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.6397 - accuracy: 0.7195
# Epoch 7/100
# 804/804 [==============================] - 1s 743us/step - loss: 0.5879 - accuracy: 0.7241
# Epoch 8/100
# 804/804 [==============================] - 1s 855us/step - loss: 0.6175 - accuracy: 0.6872
# Epoch 9/100
# 804/804 [==============================] - 1s 752us/step - loss: 0.5887 - accuracy: 0.7146
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5532 - accuracy: 0.7286 - 212ms/epoch - 791us/step
# Loss: 0.5531889796257019, Accuracy: 0.7286297082901001

# %%
# Export our model to HDF5 file

nn_model.save("AlphabetSoupCharity_Optimization.h5")
